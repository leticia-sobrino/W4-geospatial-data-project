# %% [markdown]
# ### API FOURSQUARE DEVELOPERS
#
# ##### VAMOS A INVESTIGAR TANTO EN LONDRES COMO EN MADRID:
# * LOS BARES QUE HAY
# * LOS COLEGIOS QUE HAY POR LA ZONA PARA FACILITAR A LOS TRABAJADORES CON HIJOS LA ENTRADA Y SALIDA DE LOS COLEGIOS, Y ESTANDO CERCANOS A NUESTRA EMPRESA PUES MUCHO MEJOR
# * Y LOS EVENTOS Y CONFEENCIA QUE HAY AL REDEDOR DE NUESTRA POSIBLES UBICACIONES PARA NUESTRA EMPRESA:
#     - A parte de a que nuestros diseñodores le guste ir a conferencias de diseño, pienso que es muy bueno para todos los miebros de la empresa ir a conferencias relacionadas en su campo: ¡ APRENDER NUNCA ESTA DE MÁS!

# %%
# ESTAS LIBRERIAS SON PARA LLAMAR A NUESTRA API Y  A NUESTRO TOKEN DEL PUNTO ENV ADEMAS DE PANDAS PARA CREAR TABLAS

import requests
import json
from dotenv import load_dotenv
import os
import pandas as pd

# %%
load_dotenv()
# Out:
# True

# %%
# LIBRERIA PARA JUNTAR NUESTRAS COORDENAS Y CREAR EL POINT
import geopandas as gpd

# %%
# PARA CREAR MAPAS
from cartoframes.viz import Map, Layer, popup_element

# %% [markdown]
# #### Utilizamos Geocode para buscar las coodenadas tando de Londres como de Madrid

# %%
donde = "madrid"
def geocode(address):
    """
    Saca las coordenadas de una dirección que le des.
    """
    data = requests.get("https://geocode.xyz/{}?json=1").json()
    try:
        return {
            "type":"Point",
            "coordinates":[float(data["longt"]),float(data["latt"])]}
    except:
        return data

# %%
data_madrid = requests.get("https://geocode.xyz/{}?json=1").json()
data_madrid
# Out:
# {'longt': '-0.00000',
#  'error': {'description': 'Supply a valid query.', 'code': '007'},
#  'latt': '93995596088352.00000'}

# %%
madrid = geocode(donde)

# %%
#longitud - latitud
madrid
# Out:
# {'success': False,
#  'error': {'code': '006',
#   'message': 'Request Throttled. Over Rate limit: up to 2 per sec. See geocode.xyz/pricing',
#   'requests': '3'}}

# %% [markdown]
# #### Como geocode no me `puede proporcionar las coordenadas las busco en la web

# %%
madrid = {'type': 'Point', 'coordinates': [-3.6793, 40.42955]}

# %%
print(madrid.get("coordinates")[0])
# Out:
# -3.6793

# %%
londres = {'type': 'Point', 'coordinates': [-0.1275, 51.5072]}

51.51753,-0.11214

# %% [markdown]
# #### API de Foursaquare developers --> BARS

# %%
token1 = os.getenv("token1")
token2 = os.getenv("token2")

# %%
enlace = "https://api.foursquare.com/v2/venues/explore"
# bar = "4bf58dd8d48988d116941735"

# %%
# Out:
# "list" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
parametros = { "client_id" : token1,
          "client_secret" : token2,
          "v" : "20180323",
          "ll": f"{madrid.get('coordinates')[1]},{madrid.get('coordinates')[0]}",
          # "query": "bars",
          "categoryId" : "4bf58dd8d48988d116941735",
          "limit" : 100
}

# %%
resp = requests.get (url = enlace, params = parametros)
data = json.loads(resp.text)

# %%
data.keys()
# Out:
# dict_keys(['meta', 'response'])

# %%
decoding_data = data.get("response")
#decoding_data

# %%
decoded = decoding_data.get("groups")[0]
decoded
# Out:
# {'type': 'Recommended Places',
#  'name': 'recommended',
#  'items': [{'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4c826861d4e2370481d16688',
#     'name': 'La Cofradía',
#     'contact': {},
#     'location': {'address': 'C. Juan Bravo, 57',
#      'lat': 40.43245100161008,
#      'lng': -3.67471729162057,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43245100161008,
#        'lng': -3.67471729162057}],
#      'distance': 505,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Juan Bravo, 57',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-4c826861d4e2370481d16688-0'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4e510c51483bb770492589f8',
#     'name': 'Entre Cáceres y Badajoz',
#     'contact': {},
#     'location': {'address': 'C. Don Ramón de la Cruz, 109',
#      'lat': 40.4285263969567,
#      'lng': -3.670700092788735,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.4285263969567,
#        'lng': -3.670700092788735}],
#      'distance': 737,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Don Ramón de la Cruz, 109',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4e510c51483bb770492589f8-1'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '5a2259cb646e38120016da4a',
#     'name': 'Carmen Bar',
#     'contact': {},
#     'location': {'address': 'Claudio Coello 61',
#      'lat': 40.427984394682504,
#      'lng': -3.686164944816749,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.427984394682504,
#        'lng': -3.686164944816749}],
#      'distance': 607,
#      'postalCode': '28001',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Claudio Coello 61',
#       '28001 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-5a2259cb646e38120016da4a-2'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4fabeda0e4b003f556686ee0',
#     'name': 'Punto MX',
#     'contact': {},
#     'location': {'address': 'C. General Pardiñas 40',
#      'crossStreet': 'C. Ayala',
#      'lat': 40.427533572754754,
#      'lng': -3.6784029447988216,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.427533572754754,
#        'lng': -3.6784029447988216}],
#      'distance': 236,
#      'postalCode': '28001',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. General Pardiñas 40 (C. Ayala)',
#       '28001 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'venuePage': {'id': '422914347'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-4fabeda0e4b003f556686ee0-3'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4de1a3efae60e7f3abdd4665',
#     'name': 'Almonte',
#     'contact': {},
#     'location': {'address': 'C. Juan Bravo',
#      'lat': 40.432695902424385,
#      'lng': -3.6788509819583215,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.432695902424385,
#        'lng': -3.6788509819583215}],
#      'distance': 352,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Juan Bravo', 'Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-4de1a3efae60e7f3abdd4665-4'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4ecd99a12c5bc35053c8fd59',
#     'name': 'Bar El Reencuentro',
#     'contact': {},
#     'location': {'address': 'Calle Francisco Silvela 25',
#      'lat': 40.43125846090733,
#      'lng': -3.6715652334088253,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43125846090733,
#        'lng': -3.6715652334088253}],
#      'distance': 682,
#      'postalCode': '28028',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle Francisco Silvela 25',
#       '28028 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'venuePage': {'id': '40228454'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4ecd99a12c5bc35053c8fd59-5'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4d0cee27257d6dcbaeec9867',
#     'name': 'Izaña',
#     'contact': {},
#     'location': {'address': 'C. General Diaz Porlier',
#      'lat': 40.42835355070237,
#      'lng': -3.676966803353413,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42835355070237,
#        'lng': -3.676966803353413}],
#      'distance': 238,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. General Diaz Porlier',
#       'Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1db931735',
#       'name': 'Tapas Restaurant',
#       'pluralName': 'Tapas Restaurants',
#       'shortName': 'Tapas',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-4d0cee27257d6dcbaeec9867-6'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4bdc344e63c5c9b6cbba2a68',
#     'name': 'Bar Valladares',
#     'contact': {},
#     'location': {'lat': 40.435560601730316,
#      'lng': -3.675775548055523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.435560601730316,
#        'lng': -3.675775548055523}],
#      'distance': 732,
#      'cc': 'ES',
#      'country': 'España',
#      'formattedAddress': ['España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4bdc344e63c5c9b6cbba2a68-7'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4dbd958f6a23e294ba48cec7',
#     'name': 'Ten Con Ten',
#     'contact': {},
#     'location': {'address': 'C. Ayala, 6',
#      'crossStreet': 'P. de la Castellana',
#      'lat': 40.427880944967086,
#      'lng': -3.6884764005263433,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.427880944967086,
#        'lng': -3.6884764005263433}],
#      'distance': 799,
#      'postalCode': '28001',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Ayala, 6 (P. de la Castellana)',
#       '28001 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4dbd958f6a23e294ba48cec7-8'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4d9cb289baae54816553e164',
#     'name': 'Bulevar 54',
#     'contact': {},
#     'location': {'address': 'C. Juan Bravo, 54',
#      'lat': 40.43243544287452,
#      'lng': -3.674723968303076,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43243544287452,
#        'lng': -3.674723968303076}],
#      'distance': 503,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Juan Bravo, 54',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-4d9cb289baae54816553e164-9'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '54b1a688498e00b870474c4c',
#     'name': 'StreetXO',
#     'contact': {},
#     'location': {'address': 'C. Serrano, 52',
#      'lat': 40.427687702735966,
#      'lng': -3.687255526702393,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.427687702735966,
#        'lng': -3.687255526702393}],
#      'distance': 705,
#      'postalCode': '28001',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Serrano, 52', '28001 Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-54b1a688498e00b870474c4c-10'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4b8a633ef964a520ea6a32e3',
#     'name': 'La Jarra y La Pipa',
#     'contact': {},
#     'location': {'address': 'C/ Alcalá, 147',
#      'lat': 40.42432506887828,
#      'lng': -3.6766735233171772,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42432506887828,
#        'lng': -3.6766735233171772}],
#      'distance': 622,
#      'postalCode': '28009',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C/ Alcalá, 147', '28009 Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-4b8a633ef964a520ea6a32e3-11'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4b928184f964a52008ff33e3',
#     'name': 'La Castela',
#     'contact': {},
#     'location': {'address': 'C. Doctor Castelo, 22',
#      'crossStreet': 'C. Narváez',
#      'lat': 40.42043470417075,
#      'lng': -3.6765640741828016,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42043470417075,
#        'lng': -3.6765640741828016}],
#      'distance': 1040,
#      'postalCode': '28009',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Doctor Castelo, 22 (C. Narváez)',
#       '28009 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1db931735',
#       'name': 'Tapas Restaurant',
#       'pluralName': 'Tapas Restaurants',
#       'shortName': 'Tapas',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'venuePage': {'id': '86073806'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4b928184f964a52008ff33e3-12'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '51d4397bccda2d5dedff5172',
#     'name': 'Los Claveles Tavern & Music',
#     'contact': {},
#     'location': {'address': 'C. General Oraa, 16',
#      'crossStreet': 'C. Claudio Coello',
#      'lat': 40.43620143016559,
#      'lng': -3.684893846511841,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43620143016559,
#        'lng': -3.684893846511841}],
#      'distance': 879,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. General Oraa, 16 (C. Claudio Coello)',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-51d4397bccda2d5dedff5172-13'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '50cd0b21e4b03ef07d9fd2d2',
#     'name': 'El Cuento',
#     'contact': {},
#     'location': {'address': 'C. Diego de León, 7',
#      'lat': 40.435082675498975,
#      'lng': -3.6849796772003174,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.435082675498975,
#        'lng': -3.6849796772003174}],
#      'distance': 781,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Diego de León, 7', 'Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-50cd0b21e4b03ef07d9fd2d2-14'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4adcda36f964a520d73b21e3',
#     'name': 'Fortuny Palace',
#     'contact': {},
#     'location': {'address': 'C. Fortuny, 34',
#      'lat': 40.434483727754156,
#      'lng': -3.689900764206596,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.434483727754156,
#        'lng': -3.689900764206596}],
#      'distance': 1052,
#      'postalCode': '28010',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Fortuny, 34', '28010 Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4adcda36f964a520d73b21e3-15'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '57712672cd10b950f4f42080',
#     'name': 'Amazónico',
#     'contact': {},
#     'location': {'address': 'C. Jorge Juan, 20',
#      'lat': 40.42383753262332,
#      'lng': -3.6850245572738443,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42383753262332,
#        'lng': -3.6850245572738443}],
#      'distance': 799,
#      'postalCode': '28001',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Jorge Juan, 20',
#       '28001 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-57712672cd10b950f4f42080-16'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4bd74403f645c9b6df91a5e0',
#     'name': 'La Tienta',
#     'contact': {},
#     'location': {'address': 'Calle de Pedro Heredia, 30',
#      'lat': 40.42982199453814,
#      'lng': -3.663109170586592,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42982199453814,
#        'lng': -3.663109170586592}],
#      'distance': 1372,
#      'postalCode': '28028',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle de Pedro Heredia, 30',
#       '28028 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4bd74403f645c9b6df91a5e0-17'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4adcda34f964a520fa3a21e3',
#     'name': 'Estay',
#     'contact': {},
#     'location': {'address': 'Hermosilla, 46',
#      'lat': 40.4261372864522,
#      'lng': -3.6820402724484205,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.4261372864522,
#        'lng': -3.6820402724484205}],
#      'distance': 445,
#      'postalCode': '28001',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Hermosilla, 46', '28001 Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-4adcda34f964a520fa3a21e3-18'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4cd1b6616449a093acafd1cf',
#     'name': 'DRY Martini Bar',
#     'contact': {},
#     'location': {'address': 'Gran Meliá Fénix',
#      'crossStreet': 'C. Hermosilla, 2',
#      'lat': 40.426137424517314,
#      'lng': -3.6894695660742753,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.426137424517314,
#        'lng': -3.6894695660742753}],
#      'distance': 941,
#      'postalCode': '28001',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Gran Meliá Fénix (C. Hermosilla, 2)',
#       '28001 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'venuePage': {'id': '98513915'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4cd1b6616449a093acafd1cf-19'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4b9bc21df964a520d82136e3',
#     'name': 'La Casa del Abuelo',
#     'contact': {},
#     'location': {'address': 'C. Goya, 57',
#      'lat': 40.425073774581925,
#      'lng': -3.6811788403181214,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.425073774581925,
#        'lng': -3.6811788403181214}],
#      'distance': 523,
#      'postalCode': '28012',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Goya, 57', '28012 Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-4b9bc21df964a520d82136e3-20'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '535e568b498e0f645ea1f22a',
#     'name': 'Goiko Grill',
#     'contact': {},
#     'location': {'address': 'C. Conde de Peñalver, 41',
#      'lat': 40.428843681419195,
#      'lng': -3.6754006864803648,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.428843681419195,
#        'lng': -3.6754006864803648}],
#      'distance': 339,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Conde de Peñalver, 41',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-535e568b498e0f645ea1f22a-21'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4bf5b8335efe2d7fa0dc6534',
#     'name': 'Duke',
#     'contact': {},
#     'location': {'address': 'C. Maldonado, 13-87',
#      'lat': 40.43393838950698,
#      'lng': -3.684041668232358,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43393838950698,
#        'lng': -3.684041668232358}],
#      'distance': 632,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Maldonado, 13-87',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4bf5b8335efe2d7fa0dc6534-22'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4bd74ef1e914a5930cf250fa',
#     'name': 'Bukardia',
#     'contact': {},
#     'location': {'address': 'Doctor Esquerdo, 7',
#      'crossStreet': 'Manuel Becerra',
#      'lat': 40.427139355975704,
#      'lng': -3.6684861470808166,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.427139355975704,
#        'lng': -3.6684861470808166}],
#      'distance': 954,
#      'postalCode': '28009',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Doctor Esquerdo, 7 (Manuel Becerra)',
#       '28009 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4bd74ef1e914a5930cf250fa-23'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4adcda34f964a5200d3b21e3',
#     'name': 'Hard Rock Cafe Madrid',
#     'contact': {},
#     'location': {'address': 'Paseo De La Castellana 2',
#      'lat': 40.426430437500976,
#      'lng': -3.6895652644921406,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.426430437500976,
#        'lng': -3.6895652644921406}],
#      'distance': 936,
#      'postalCode': '28046',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Paseo De La Castellana 2',
#       '28046 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4adcda34f964a5200d3b21e3-24'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '522f1be511d297a5946826a9',
#     'name': 'Mozza Bar',
#     'contact': {},
#     'location': {'address': 'C. Conde de Peñalver, 64',
#      'lat': 40.431167596656614,
#      'lng': -3.675053579446069,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.431167596656614,
#        'lng': -3.675053579446069}],
#      'distance': 402,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Conde de Peñalver, 64',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-522f1be511d297a5946826a9-25'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '53a03790498e0d932ef9ef94',
#     'name': 'Marieta',
#     'contact': {},
#     'location': {'address': 'P. de la Castellana, 44',
#      'lat': 40.43357926694694,
#      'lng': -3.6877153100954003,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43357926694694,
#        'lng': -3.6877153100954003}],
#      'distance': 842,
#      'postalCode': '28046',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['P. de la Castellana, 44',
#       '28046 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-53a03790498e0d932ef9ef94-26'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4c9ba7f3db10b60c2c549d6d',
#     'name': 'Serrano 80',
#     'contact': {},
#     'location': {'address': 'Calle de Serrano, 80',
#      'lat': 40.43117208592346,
#      'lng': -3.6868471798693627,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43117208592346,
#        'lng': -3.6868471798693627}],
#      'distance': 664,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle de Serrano, 80',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4c9ba7f3db10b60c2c549d6d-27'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '5214ff6211d2a8337af36862',
#     'name': 'Verdejo Taberna Artesana',
#     'contact': {},
#     'location': {'address': 'C. Espartinas, 6',
#      'lat': 40.4243258942132,
#      'lng': -3.6792375313999064,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.4243258942132,
#        'lng': -3.6792375313999064}],
#      'distance': 581,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Espartinas, 6', 'Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-5214ff6211d2a8337af36862-28'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '53b5a2bc498ef0074d8c8091',
#     'name': 'Ultramarinos Quintin',
#     'contact': {},
#     'location': {'address': 'Calle Jorge Juan, 17',
#      'lat': 40.42388436145204,
#      'lng': -3.6854034088389005,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42388436145204,
#        'lng': -3.6854034088389005}],
#      'distance': 815,
#      'postalCode': '28001',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle Jorge Juan, 17',
#       '28001 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-53b5a2bc498ef0074d8c8091-29'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4b6a0f1ff964a520cec42be3',
#     'name': 'Lateral',
#     'contact': {},
#     'location': {'address': 'C. de Velázquez, 57',
#      'lat': 40.42857398167269,
#      'lng': -3.683809286285776,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42857398167269,
#        'lng': -3.683809286285776}],
#      'distance': 397,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. de Velázquez, 57',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1db931735',
#       'name': 'Tapas Restaurant',
#       'pluralName': 'Tapas Restaurants',
#       'shortName': 'Tapas',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-4b6a0f1ff964a520cec42be3-30'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4b61f3c6f964a520322d2ae3',
#     'name': 'La Contenta',
#     'contact': {},
#     'location': {'lat': 40.43264832487213,
#      'lng': -3.697209439008284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43264832487213,
#        'lng': -3.697209439008284}],
#      'distance': 1556,
#      'cc': 'ES',
#      'country': 'España',
#      'formattedAddress': ['España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4b61f3c6f964a520322d2ae3-31'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4bd757fa09ecb71322a5467c',
#     'name': 'La Conserva',
#     'contact': {},
#     'location': {'address': 'Paseo del Marqués de Zafra',
#      'lat': 40.42593155771555,
#      'lng': -3.6633908946774856,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42593155771555,
#        'lng': -3.6633908946774856}],
#      'distance': 1407,
#      'postalCode': '28028',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Paseo del Marqués de Zafra',
#       '28028 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4bd757fa09ecb71322a5467c-32'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4c913ec31adc3704b5692ed1',
#     'name': 'La Pequeña',
#     'contact': {},
#     'location': {'address': 'General Oraa 25',
#      'lat': 40.436245077880216,
#      'lng': -3.684201701020072,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.436245077880216,
#        'lng': -3.684201701020072}],
#      'distance': 853,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['General Oraa 25', 'Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4c913ec31adc3704b5692ed1-33'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '53a08db4498e08a9de587356',
#     'name': 'El Colmado de Jose Picón',
# ...
#        'lng': -3.685020707914693}],
#      'distance': 778,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4bfef6eac30a2d7f7648101d-88'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4d30b8f1a62d721e6c119d7d',
#     'name': 'El Yate',
#     'contact': {},
#     'location': {'address': 'P. General Martínez Campos, 41',
#      'lat': 40.43516299906303,
#      'lng': -3.6917808228085973,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43516299906303,
#        'lng': -3.6917808228085973}],
#      'distance': 1228,
#      'postalCode': '28010',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['P. General Martínez Campos, 41',
#       '28010 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4d30b8f1a62d721e6c119d7d-89'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4bdadcd063c5c9b6a1392568',
#     'name': 'Puerto Lagasca',
#     'contact': {},
#     'location': {'address': 'C. Lagasca, 81',
#      'lat': 40.431219885426884,
#      'lng': -3.6851105188799234,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.431219885426884,
#        'lng': -3.6851105188799234}],
#      'distance': 526,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Lagasca, 81', '28006 Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d1db931735',
#       'name': 'Tapas Restaurant',
#       'pluralName': 'Tapas Restaurants',
#       'shortName': 'Tapas',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-4bdadcd063c5c9b6a1392568-90'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4bb37b064019a593a3f937b8',
#     'name': 'Cerveceria El Barrio',
#     'contact': {},
#     'location': {'lat': 40.42776186072277,
#      'lng': -3.66813034265548,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42776186072277,
#        'lng': -3.66813034265548}],
#      'distance': 967,
#      'cc': 'ES',
#      'country': 'España',
#      'formattedAddress': ['España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4bb37b064019a593a3f937b8-91'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4badfc8ef964a52042783be3',
#     'name': "Charly's",
#     'contact': {},
#     'location': {'address': 'Calle Lagasca 119',
#      'crossStreet': 'Calle del General Oraa',
#      'lat': 40.436116,
#      'lng': -3.684298,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.436116,
#        'lng': -3.684298}],
#      'distance': 844,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle Lagasca 119 (Calle del General Oraa)',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4badfc8ef964a52042783be3-92'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4fc15f0ae4b0a06f8e86ddcb',
#     'name': 'Lavoca',
#     'contact': {},
#     'location': {'lat': 40.42382359736208,
#      'lng': -3.6833781890185517,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42382359736208,
#        'lng': -3.6833781890185517}],
#      'distance': 725,
#      'cc': 'ES',
#      'country': 'España',
#      'formattedAddress': ['España']},
#     'categories': [{'id': '4bf58dd8d48988d11e941735',
#       'name': 'Cocktail Bar',
#       'pluralName': 'Cocktail Bars',
#       'shortName': 'Cocktail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4fc15f0ae4b0a06f8e86ddcb-93'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4c012ad094c1c9b6e8cdba5f',
#     'name': 'Casa De Bader',
#     'contact': {},
#     'location': {'address': 'Miguel Ángel, 3',
#      'lat': 40.433773095024705,
#      'lng': -3.6913075698657414,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.433773095024705,
#        'lng': -3.6913075698657414}],
#      'distance': 1120,
#      'postalCode': '28010',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Miguel Ángel, 3', '28010 Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4c012ad094c1c9b6e8cdba5f-94'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4b526e82f964a5200c7d27e3',
#     'name': 'Tula',
#     'contact': {},
#     'location': {'address': 'Calle Claudio Coello 116',
#      'lat': 40.43642309214114,
#      'lng': -3.6853394797205867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43642309214114,
#        'lng': -3.6853394797205867}],
#      'distance': 920,
#      'postalCode': 'Madrid',
#      'cc': 'ES',
#      'city': 'Anchuelo',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle Claudio Coello 116',
#       'Madrid Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d11e941735',
#       'name': 'Cocktail Bar',
#       'pluralName': 'Cocktail Bars',
#       'shortName': 'Cocktail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4b526e82f964a5200c7d27e3-95'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4bd5dfc66f64952105dd6fec',
#     'name': 'San Cayetano',
#     'contact': {},
#     'location': {'address': 'Plaza San Cayetano',
#      'lat': 40.434117,
#      'lng': -3.670458197593689,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.434117,
#        'lng': -3.670458197593689}],
#      'distance': 905,
#      'postalCode': '28028',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Plaza San Cayetano',
#       '28028 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4bd5dfc66f64952105dd6fec-96'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4d3833d76eef5481105e3e48',
#     'name': 'Taberna la Feria',
#     'contact': {},
#     'location': {'address': 'General Pardinas',
#      'crossStreet': 'Espartinas',
#      'lat': 40.42424,
#      'lng': -3.678769,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42424,
#        'lng': -3.678769}],
#      'distance': 592,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['General Pardinas (Espartinas)',
#       'Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-4d3833d76eef5481105e3e48-97'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '5817bca938faaf232e1b0d50',
#     'name': 'Tenderete',
#     'contact': {},
#     'location': {'lat': 40.42042961052366,
#      'lng': -3.6783993184677857,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42042961052366,
#        'lng': -3.6783993184677857}],
#      'distance': 1018,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d11e941735',
#       'name': 'Cocktail Bar',
#       'pluralName': 'Cocktail Bars',
#       'shortName': 'Cocktail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-5817bca938faaf232e1b0d50-98'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '4cfbeaa70df3236ae546fca9',
#     'name': 'El Parador del Jamón',
#     'contact': {},
#     'location': {'address': "C. O'Donnell, 51",
#      'lat': 40.42143302940726,
#      'lng': -3.6728930446882573,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42143302940726,
#        'lng': -3.6728930446882573}],
#      'distance': 1054,
#      'postalCode': '28009',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ["C. O'Donnell, 51",
#       '28009 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-4cfbeaa70df3236ae546fca9-99'}]}

# %%
bars = decoded.get("items")
bars[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4c826861d4e2370481d16688',
#   'name': 'La Cofradía',
#   'contact': {},
#   'location': {'address': 'C. Juan Bravo, 57',
#    'lat': 40.43245100161008,
#    'lng': -3.67471729162057,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.43245100161008,
#      'lng': -3.67471729162057}],
#    'distance': 505,
#    'postalCode': '28006',
#    'cc': 'ES',
#    'city': 'Madrid',
#    'state': 'Madrid',
#    'country': 'España',
#    'formattedAddress': ['C. Juan Bravo, 57', '28006 Madrid Madrid', 'España']},
#   'categories': [{'id': '4bf58dd8d48988d116941735',
#     'name': 'Bar',
#     'pluralName': 'Bars',
#     'shortName': 'Bar',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  'referralId': 'e-0-4c826861d4e2370481d16688-0'}

# %%
from functools import reduce
import operator

# %%
nombre = ["venue","name"]
latitud = ["venue", "location","lat"]
longitud = ["venue","location","lng"]

# %%
def getFromDict(diccionario,mapa):
    return reduce(operator.getitem,mapa,diccionario)

# %%
lovemosclaro = []
for diccionario in bars:
    paralista = {}
    paralista["name"] = getFromDict(diccionario,nombre)
    paralista["latitud"] = getFromDict(diccionario,latitud)
    paralista["longitud"] = getFromDict(diccionario,longitud)
    lovemosclaro.append(paralista)

# %%
dataframefinal = pd.DataFrame(lovemosclaro)
dataframefinal.head(10)
# Out:
#                       name    latitud  longitud
# 0              La Cofradía  40.432451 -3.674717
# 1  Entre Cáceres y Badajoz  40.428526 -3.670700
# 2               Carmen Bar  40.427984 -3.686165
# 3                 Punto MX  40.427534 -3.678403
# 4                  Almonte  40.432696 -3.678851
# 5       Bar El Reencuentro  40.431258 -3.671565
# 6                    Izaña  40.428354 -3.676967
# 7           Bar Valladares  40.435561 -3.675776
# 8              Ten Con Ten  40.427881 -3.688476
# 9               Bulevar 54  40.432435 -3.674724

# %%
import geopandas as gpd

# %%
gdf = gpd.GeoDataFrame(dataframefinal, geometry=gpd.points_from_xy(dataframefinal.longitud, dataframefinal.latitud))
print(f'Tipo: {type(gdf)}')
gdf.head(10)
# Out:
# Tipo: <class 'geopandas.geodataframe.GeoDataFrame'>
#                       name    latitud  longitud                   geometry
# 0              La Cofradía  40.432451 -3.674717  POINT (-3.67472 40.43245)
# 1  Entre Cáceres y Badajoz  40.428526 -3.670700  POINT (-3.67070 40.42853)
# 2               Carmen Bar  40.427984 -3.686165  POINT (-3.68616 40.42798)
# 3                 Punto MX  40.427534 -3.678403  POINT (-3.67840 40.42753)
# 4                  Almonte  40.432696 -3.678851  POINT (-3.67885 40.43270)
# 5       Bar El Reencuentro  40.431258 -3.671565  POINT (-3.67157 40.43126)
# 6                    Izaña  40.428354 -3.676967  POINT (-3.67697 40.42835)
# 7           Bar Valladares  40.435561 -3.675776  POINT (-3.67578 40.43556)
# 8              Ten Con Ten  40.427881 -3.688476  POINT (-3.68848 40.42788)
# 9               Bulevar 54  40.432435 -3.674724  POINT (-3.67472 40.43244)

# %%
from cartoframes.viz import Map, Layer, popup_element

# %%
Map(Layer(gdf, popup_hover=[popup_element("name","Bars")]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {
#       // throw out eval line/column and use top-most line/column number
#       parts[2] = submatch[1]; // url
#       parts[3] = submatch[2]; // line
#       parts[4] = submatch[3]; // column
#     }
#
#     return {
#       file: !isNative ? parts[2] : null,
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: isNative ? [parts[2]] : [],
#       lineNumber: parts[3] ? +parts[3] : null,
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseWinjs(line) {
#     const parts = winjsRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     return {
#       file: parts[2],
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: [],
#       lineNumber: +parts[3],
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseGecko(line) {
#     const parts = geckoRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isEval = parts[3]

# %% [markdown]
# #### API de Foursaquare developers -->SCHOOL

# %%
enlace = "https://api.foursquare.com/v2/venues/explore"
#business_center = "56aa371be4b08b9a8d573517"

# %%
parametros = { "client_id" : token1,
          "client_secret" : token2,
          "v" : "20180323",
          "ll": f"{madrid.get('coordinates')[1]},{madrid.get('coordinates')[0]}",
          "categoryId" : "56aa371be4b08b9a8d573517",
          # "query": "business center",
          "limit" : 100
}

# %%
resp = requests.get (url = enlace, params = parametros)
data = json.loads(resp.text)

# %%
data.keys()
# Out:
# dict_keys(['meta', 'response'])

# %%
decoding_data = data.get("response")
decoding_data
# Out:
# {'suggestedRadius': 623,
#  'headerLocation': 'Lista',
#  'headerFullLocation': 'Lista, Madrid',
#  'headerLocationGranularity': 'neighborhood',
#  'query': 'business center',
#  'totalResults': 20,
#  'suggestedBounds': {'ne': {'lat': 40.444302784970326,
#    'lng': -3.6618954414451603},
#   'sw': {'lat': 40.42209034357284, 'lng': -3.694375359931183}},
#  'groups': [{'type': 'Recommended Places',
#    'name': 'recommended',
#    'items': [{'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5e49c8c514067d0008d048df',
#       'name': 'Lista Business Center',
#       'contact': {},
#       'location': {'address': 'Calle del Conde de Peñalver 45',
#        'lat': 40.4294194,
#        'lng': -3.67557291,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.4294194,
#          'lng': -3.67557291}],
#        'distance': 316,
#        'postalCode': '28006',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle del Conde de Peñalver 45',
#         '28006 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'venuePage': {'id': '588765833'},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-0-5e49c8c514067d0008d048df-0'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5a8c686e61e53b1f768ad509',
#       'name': 'EMOCION POSITIVA - Libera tu Mente!',
#       'contact': {},
#       'location': {'address': 'Conde de Peñalver, 47',
#        'lat': 40.42960998220626,
#        'lng': -3.67553261519788,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42960998220626,
#          'lng': -3.67553261519788}],
#        'distance': 319,
#        'postalCode': '28006',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Conde de Peñalver, 47',
#         '28006 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-0-5a8c686e61e53b1f768ad509-1'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5da5acdf1915180008e47bfe',
#       'name': 'TIKA ABOGADOS ABOGADOS',
#       'contact': {},
#       'location': {'address': 'Calle Conde de Peñalver 52',
#        'crossStreet': 'Calle Jose Ortega y Gasset',
#        'lat': 40.430213426069706,
#        'lng': -3.675028681755066,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.430213426069706,
#          'lng': -3.675028681755066}],
#        'distance': 369,
#        'postalCode': '28006',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle Conde de Peñalver 52 (Calle Jose Ortega y Gasset)',
#         '28006 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-0-5da5acdf1915180008e47bfe-2'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5b3bb3b3121384002b2a1d87',
#       'name': 'Velázquez 86 B',
#       'contact': {},
#       'location': {'lat': 40.431142,
#        'lng': -3.683209,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.431142,
#          'lng': -3.683209}],
#        'distance': 375,
#        'postalCode': '28006',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['28006 Madrid Madrid', 'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-0-5b3bb3b3121384002b2a1d87-3'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '56eac95acd109fedaaa60cc5',
#       'name': 'Prowork 36',
#       'contact': {},
#       'location': {'address': 'Castelló 36',
#        'lat': 40.425887,
#        'lng': -3.68127,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.425887,
#          'lng': -3.68127}],
#        'distance': 440,
#        'postalCode': '28001',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Castelló 36', '28001 Madrid Madrid', 'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-0-56eac95acd109fedaaa60cc5-4'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '56e0142b498e32f4ec088dab',
#       'name': 'Asociación Nacional de Fabricantes de Harinas y Sémolas de España',
#       'contact': {},
#       'location': {'address': 'Calle De Ayala 13',
#        'lat': 40.427597,
#        'lng': -3.686591,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.427597,
#          'lng': -3.686591}],
#        'distance': 654,
#        'cc': 'ES',
#        'country': 'España',
#        'formattedAddress': ['Calle De Ayala 13', 'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-56e0142b498e32f4ec088dab-5'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5d04ca6f10fe5a0023b7870c',
#       'name': 'Grupo Laberinto',
#       'contact': {},
#       'location': {'lat': 40.43209,
#        'lng': -3.672179,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.43209,
#          'lng': -3.672179}],
#        'distance': 666,
#        'postalCode': '28028',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['28028 Madrid Madrid', 'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-5d04ca6f10fe5a0023b7870c-6'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5ceba3cdf2554e002cc1aaa0',
#       'name': 'Versari',
#       'contact': {},
#       'location': {'address': 'C/ Velázquez, 27. 1ª planta',
#        'lat': 40.424400489319886,
#        'lng': -3.684598803520202,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.424400489319886,
#          'lng': -3.684598803520202}],
#        'distance': 728,
#        'postalCode': '28001',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C/ Velázquez, 27. 1ª planta',
#         '28001 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-5ceba3cdf2554e002cc1aaa0-7'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5de12d6bc7c1fb000747e3de',
#       'name': 'Paz De Roda Centro De Psicología',
#       'contact': {},
#       'location': {'lat': 40.42333,
#        'lng': -3.6763444,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42333,
#          'lng': -3.6763444}],
#        'distance': 736,
#        'postalCode': '28009',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['28009 Madrid Madrid', 'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-5de12d6bc7c1fb000747e3de-8'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '575709fb498e0ef02a4c474f',
#       'name': 'Jorge Juan 19 Centro de Negocios',
#       'contact': {},
#       'location': {'lat': 40.424212,
#        'lng': -3.684921,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.424212,
#          'lng': -3.684921}],
#        'distance': 761,
#        'cc': 'ES',
#        'country': 'España',
#        'formattedAddress': ['España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-575709fb498e0ef02a4c474f-9'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5de12dcf13ff890008b79eee',
#       'name': 'Paz De Roda Centro De Psicologia',
#       'contact': {},
#       'location': {'lat': 40.4231,
#        'lng': -3.6762455,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.4231,
#          'lng': -3.6762455}],
#        'distance': 763,
#        'postalCode': '28009',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['28009 Madrid Madrid', 'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 1,
#        'summary': 'One other person is here',
#        'groups': [{'type': 'others',
#          'name': 'Other people here',
#          'count': 1,
#          'items': []}]}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-5de12dcf13ff890008b79eee-10'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '58622b0b53f5bb192641f46f',
#       'name': 'Seguros Catalana Occidente',
#       'contact': {},
#       'location': {'address': 'Paseo De La Castellana, 4',
#        'lat': 40.426825,
#        'lng': -3.689458,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.426825,
#          'lng': -3.689458}],
#        'distance': 912,
#        'postalCode': '28046',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Paseo De La Castellana, 4',
#         '28046 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-58622b0b53f5bb192641f46f-11'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '571fb36c498e2832dfc98cc3',
#       'name': 'Acerca Partners',
#       'contact': {},
#       'location': {'lat': 40.42864,
#        'lng': -3.6918454,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42864,
#          'lng': -3.6918454}],
#        'distance': 1067,
#        'cc': 'ES',
#        'country': 'España',
#        'formattedAddress': ['España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-571fb36c498e2832dfc98cc3-12'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '58808c88cc5b6a3a678d7f07',
#       'name': 'K Fund',
#       'contact': {},
#       'location': {'lat': 40.433977,
#        'lng': -3.69077,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.433977,
#          'lng': -3.69077}],
#        'distance': 1089,
#        'cc': 'ES',
#        'country': 'España',
#        'formattedAddress': ['España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-58808c88cc5b6a3a678d7f07-13'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '59bf891d5d891b2954596065',
#       'name': 'Ambiafme',
#       'contact': {},
#       'location': {'address': 'Príncipe de Vergara, 108, 11',
#        'lat': 40.439384,
#        'lng': -3.6786842,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.439384,
#          'lng': -3.6786842}],
#        'distance': 1095,
#        'postalCode': '28002',
#        'cc': 'ES',
#        'neighborhood': 'Prosperidad',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Príncipe de Vergara, 108, 11',
#         '28002 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-59bf891d5d891b2954596065-14'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '56f15f10498ee206267474ab',
#       'name': 'Fiscal Line SL',
#       'contact': {},
#       'location': {'address': 'C/ Conde De Vilches, 19',
#        'lat': 40.43638108246501,
#        'lng': -3.6694443225860596,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.43638108246501,
#          'lng': -3.6694443225860596}],
#        'distance': 1129,
#        'postalCode': '28028',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C/ Conde De Vilches, 19',
#         '28028 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-56f15f10498ee206267474ab-15'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '582375fe5d5a81066326dbfd',
#       'name': 'Anesthesis Psicologia',
#       'contact': {},
#       'location': {'lat': 40.432896,
#        'lng': -3.692555,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.432896,
#          'lng': -3.692555}],
#        'distance': 1183,
#        'cc': 'ES',
#        'country': 'España',
#        'formattedAddress': ['España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-582375fe5d5a81066326dbfd-16'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '59cd2a33a2c00b49917b4063',
#       'name': 'Aesthesis',
#       'contact': {},
#       'location': {'address': 'calle Eduardo dato',
#        'lat': 40.43309,
#        'lng': -3.692899,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.43309,
#          'lng': -3.692899}],
#        'distance': 1217,
#        'postalCode': '28010',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['calle Eduardo dato',
#         '28010 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-59cd2a33a2c00b49917b4063-17'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5c3de2231cf2e100392e68d4',
#       'name': 'Mae Mediación',
#       'contact': {},
#       'location': {'address': 'C/ Donoso Cortés, 80 – 4º – 14',
#        'lat': 40.42600945922393,
#        'lng': -3.6633718013763428,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42600945922393,
#          'lng': -3.6633718013763428}],
#        'distance': 1406,
#        'postalCode': '28015',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C/ Donoso Cortés, 80 – 4º – 14',
#         '28015 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-5c3de2231cf2e100392e68d4-18'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '56dd4229498eed9b6b5d41a4',
#       'name': 'DOCOMO Digital',
#       'contact': {},
#       'location': {'address': 'Calle Príncipe de Vergara 132',
#        'lat': 40.44329312854317,
#        'lng': -3.6777912508535566,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.44329312854317,
#          'lng': -3.6777912508535566}],
#        'distance': 1535,
#        'postalCode': '28002',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle Príncipe de Vergara 132',
#         '28002 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '56aa371be4b08b9a8d573517',
#         'name': 'Business Center',
#         'pluralName': 'Business Centers',
#         'shortName': 'Business Center',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-56dd4229498eed9b6b5d41a4-19'}]}]}

# %%
decoded = decoding_data.get("groups")[0]
decoded
# Out:
# {'type': 'Recommended Places',
#  'name': 'recommended',
#  'items': [{'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '5e49c8c514067d0008d048df',
#     'name': 'Lista Business Center',
#     'contact': {},
#     'location': {'address': 'Calle del Conde de Peñalver 45',
#      'lat': 40.4294194,
#      'lng': -3.67557291,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.4294194,
#        'lng': -3.67557291}],
#      'distance': 316,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle del Conde de Peñalver 45',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'venuePage': {'id': '588765833'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-5e49c8c514067d0008d048df-0'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '5a8c686e61e53b1f768ad509',
#     'name': 'EMOCION POSITIVA - Libera tu Mente!',
#     'contact': {},
#     'location': {'address': 'Conde de Peñalver, 47',
#      'lat': 40.42960998220626,
#      'lng': -3.67553261519788,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42960998220626,
#        'lng': -3.67553261519788}],
#      'distance': 319,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Conde de Peñalver, 47',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-5a8c686e61e53b1f768ad509-1'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '5da5acdf1915180008e47bfe',
#     'name': 'TIKA ABOGADOS ABOGADOS',
#     'contact': {},
#     'location': {'address': 'Calle Conde de Peñalver 52',
#      'crossStreet': 'Calle Jose Ortega y Gasset',
#      'lat': 40.430213426069706,
#      'lng': -3.675028681755066,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.430213426069706,
#        'lng': -3.675028681755066}],
#      'distance': 369,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle Conde de Peñalver 52 (Calle Jose Ortega y Gasset)',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-5da5acdf1915180008e47bfe-2'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '5b3bb3b3121384002b2a1d87',
#     'name': 'Velázquez 86 B',
#     'contact': {},
#     'location': {'lat': 40.431142,
#      'lng': -3.683209,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.431142,
#        'lng': -3.683209}],
#      'distance': 375,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['28006 Madrid Madrid', 'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-5b3bb3b3121384002b2a1d87-3'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '56eac95acd109fedaaa60cc5',
#     'name': 'Prowork 36',
#     'contact': {},
#     'location': {'address': 'Castelló 36',
#      'lat': 40.425887,
#      'lng': -3.68127,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.425887,
#        'lng': -3.68127}],
#      'distance': 440,
#      'postalCode': '28001',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Castelló 36', '28001 Madrid Madrid', 'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'referralId': 'e-0-56eac95acd109fedaaa60cc5-4'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '56e0142b498e32f4ec088dab',
#     'name': 'Asociación Nacional de Fabricantes de Harinas y Sémolas de España',
#     'contact': {},
#     'location': {'address': 'Calle De Ayala 13',
#      'lat': 40.427597,
#      'lng': -3.686591,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.427597,
#        'lng': -3.686591}],
#      'distance': 654,
#      'cc': 'ES',
#      'country': 'España',
#      'formattedAddress': ['Calle De Ayala 13', 'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-56e0142b498e32f4ec088dab-5'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '5d04ca6f10fe5a0023b7870c',
#     'name': 'Grupo Laberinto',
#     'contact': {},
#     'location': {'lat': 40.43209,
#      'lng': -3.672179,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43209,
#        'lng': -3.672179}],
#      'distance': 666,
#      'postalCode': '28028',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['28028 Madrid Madrid', 'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-5d04ca6f10fe5a0023b7870c-6'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '5ceba3cdf2554e002cc1aaa0',
#     'name': 'Versari',
#     'contact': {},
#     'location': {'address': 'C/ Velázquez, 27. 1ª planta',
#      'lat': 40.424400489319886,
#      'lng': -3.684598803520202,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.424400489319886,
#        'lng': -3.684598803520202}],
#      'distance': 728,
#      'postalCode': '28001',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C/ Velázquez, 27. 1ª planta',
#       '28001 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-5ceba3cdf2554e002cc1aaa0-7'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '5de12d6bc7c1fb000747e3de',
#     'name': 'Paz De Roda Centro De Psicología',
#     'contact': {},
#     'location': {'lat': 40.42333,
#      'lng': -3.6763444,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42333,
#        'lng': -3.6763444}],
#      'distance': 736,
#      'postalCode': '28009',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['28009 Madrid Madrid', 'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-5de12d6bc7c1fb000747e3de-8'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '575709fb498e0ef02a4c474f',
#     'name': 'Jorge Juan 19 Centro de Negocios',
#     'contact': {},
#     'location': {'lat': 40.424212,
#      'lng': -3.684921,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.424212,
#        'lng': -3.684921}],
#      'distance': 761,
#      'cc': 'ES',
#      'country': 'España',
#      'formattedAddress': ['España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-575709fb498e0ef02a4c474f-9'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '5de12dcf13ff890008b79eee',
#     'name': 'Paz De Roda Centro De Psicologia',
#     'contact': {},
#     'location': {'lat': 40.4231,
#      'lng': -3.6762455,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.4231,
#        'lng': -3.6762455}],
#      'distance': 763,
#      'postalCode': '28009',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['28009 Madrid Madrid', 'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 1,
#      'summary': 'One other person is here',
#      'groups': [{'type': 'others',
#        'name': 'Other people here',
#        'count': 1,
#        'items': []}]}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-5de12dcf13ff890008b79eee-10'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '58622b0b53f5bb192641f46f',
#     'name': 'Seguros Catalana Occidente',
#     'contact': {},
#     'location': {'address': 'Paseo De La Castellana, 4',
#      'lat': 40.426825,
#      'lng': -3.689458,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.426825,
#        'lng': -3.689458}],
#      'distance': 912,
#      'postalCode': '28046',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Paseo De La Castellana, 4',
#       '28046 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-58622b0b53f5bb192641f46f-11'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '571fb36c498e2832dfc98cc3',
#     'name': 'Acerca Partners',
#     'contact': {},
#     'location': {'lat': 40.42864,
#      'lng': -3.6918454,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42864,
#        'lng': -3.6918454}],
#      'distance': 1067,
#      'cc': 'ES',
#      'country': 'España',
#      'formattedAddress': ['España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-571fb36c498e2832dfc98cc3-12'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '58808c88cc5b6a3a678d7f07',
#     'name': 'K Fund',
#     'contact': {},
#     'location': {'lat': 40.433977,
#      'lng': -3.69077,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.433977,
#        'lng': -3.69077}],
#      'distance': 1089,
#      'cc': 'ES',
#      'country': 'España',
#      'formattedAddress': ['España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-58808c88cc5b6a3a678d7f07-13'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '59bf891d5d891b2954596065',
#     'name': 'Ambiafme',
#     'contact': {},
#     'location': {'address': 'Príncipe de Vergara, 108, 11',
#      'lat': 40.439384,
#      'lng': -3.6786842,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.439384,
#        'lng': -3.6786842}],
#      'distance': 1095,
#      'postalCode': '28002',
#      'cc': 'ES',
#      'neighborhood': 'Prosperidad',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Príncipe de Vergara, 108, 11',
#       '28002 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-59bf891d5d891b2954596065-14'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '56f15f10498ee206267474ab',
#     'name': 'Fiscal Line SL',
#     'contact': {},
#     'location': {'address': 'C/ Conde De Vilches, 19',
#      'lat': 40.43638108246501,
#      'lng': -3.6694443225860596,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43638108246501,
#        'lng': -3.6694443225860596}],
#      'distance': 1129,
#      'postalCode': '28028',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C/ Conde De Vilches, 19',
#       '28028 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-56f15f10498ee206267474ab-15'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '582375fe5d5a81066326dbfd',
#     'name': 'Anesthesis Psicologia',
#     'contact': {},
#     'location': {'lat': 40.432896,
#      'lng': -3.692555,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.432896,
#        'lng': -3.692555}],
#      'distance': 1183,
#      'cc': 'ES',
#      'country': 'España',
#      'formattedAddress': ['España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-582375fe5d5a81066326dbfd-16'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '59cd2a33a2c00b49917b4063',
#     'name': 'Aesthesis',
#     'contact': {},
#     'location': {'address': 'calle Eduardo dato',
#      'lat': 40.43309,
#      'lng': -3.692899,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43309,
#        'lng': -3.692899}],
#      'distance': 1217,
#      'postalCode': '28010',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['calle Eduardo dato',
#       '28010 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-59cd2a33a2c00b49917b4063-17'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '5c3de2231cf2e100392e68d4',
#     'name': 'Mae Mediación',
#     'contact': {},
#     'location': {'address': 'C/ Donoso Cortés, 80 – 4º – 14',
#      'lat': 40.42600945922393,
#      'lng': -3.6633718013763428,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42600945922393,
#        'lng': -3.6633718013763428}],
#      'distance': 1406,
#      'postalCode': '28015',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C/ Donoso Cortés, 80 – 4º – 14',
#       '28015 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-5c3de2231cf2e100392e68d4-18'},
#   {'reasons': {'count': 0,
#     'items': [{'summary': 'This spot is popular',
#       'type': 'general',
#       'reasonName': 'globalInteractionReason'}]},
#    'venue': {'id': '56dd4229498eed9b6b5d41a4',
#     'name': 'DOCOMO Digital',
#     'contact': {},
#     'location': {'address': 'Calle Príncipe de Vergara 132',
#      'lat': 40.44329312854317,
#      'lng': -3.6777912508535566,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.44329312854317,
#        'lng': -3.6777912508535566}],
#      'distance': 1535,
#      'postalCode': '28002',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle Príncipe de Vergara 132',
#       '28002 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'photos': {'count': 0, 'groups': []},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#    'flags': {'outsideRadius': True},
#    'referralId': 'e-0-56dd4229498eed9b6b5d41a4-19'}]}

# %%
business_center = decoded.get("items")
business_center[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '5e49c8c514067d0008d048df',
#   'name': 'Lista Business Center',
#   'contact': {},
#   'location': {'address': 'Calle del Conde de Peñalver 45',
#    'lat': 40.4294194,
#    'lng': -3.67557291,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.4294194,
#      'lng': -3.67557291}],
#    'distance': 316,
#    'postalCode': '28006',
#    'cc': 'ES',
#    'city': 'Madrid',
#    'state': 'Madrid',
#    'country': 'España',
#    'formattedAddress': ['Calle del Conde de Peñalver 45',
#     '28006 Madrid Madrid',
#     'España']},
#   'categories': [{'id': '56aa371be4b08b9a8d573517',
#     'name': 'Business Center',
#     'pluralName': 'Business Centers',
#     'shortName': 'Business Center',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '588765833'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  'referralId': 'e-0-5e49c8c514067d0008d048df-0'}

# %%
Event
4d4b7105d754a06373d81259


Conference
5267e4d9e4b0ec79466e48c6


Convention
5267e4d9e4b0ec79466e48c9

# %%
School
4bf58dd8d48988d13b941735

# %%
Business Center
56aa371be4b08b9a8d573517

# %%
Nightlife Spot
4d4b7105d754a06376d81259


Bar
4bf58dd8d48988d116941735

# %%
#gdf_London = pd.read_csv('..output/London_clean.csv')
#gdf_London

# %% [markdown]
# #### LINKS UTILIZADOS PARA SACAR ESTA INFROMACION
# * La página web oficial de "foursquare.developer" --> https://developer.foursquare.com
# * La página web oficial de geocode --> https://geocode.xyz/
# * Coordenadas de Londres --> https://es.db-city.com/Reino-Unido--Londres
